# %% [markdown]
# **Programming Foundations: Fundamentals Certificate:**

# %% [markdown]
# ![Screen%20Shot%202022-01-23%20at%2012.32.51%20PM.png](attachment:Screen%20Shot%202022-01-23%20at%2012.32.51%20PM.png)
