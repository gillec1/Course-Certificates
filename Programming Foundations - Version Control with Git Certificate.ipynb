# %% [markdown]
# **Programming Foundations: Version Control with Git Certificate:**

# %% [markdown]
# ![Screen%20Shot%202022-01-23%20at%2012.42.08%20PM.png](attachment:Screen%20Shot%202022-01-23%20at%2012.42.08%20PM.png)
