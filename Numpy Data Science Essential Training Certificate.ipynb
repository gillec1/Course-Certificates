# %% [markdown]
# **Numpy Data Science Essential Training Certificate:**

# %% [markdown]
# ![Screen%20Shot%202022-01-23%20at%201.00.15%20PM.png](attachment:Screen%20Shot%202022-01-23%20at%201.00.15%20PM.png)
