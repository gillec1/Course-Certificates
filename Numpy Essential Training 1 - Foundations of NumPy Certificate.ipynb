# %% [markdown]
# **Numpy Essential Training 1: Foundations of NumPy Certificate**

# %% [markdown]
# ![Screen%20Shot%202022-01-19%20at%209.33.17%20PM.png](attachment:Screen%20Shot%202022-01-19%20at%209.33.17%20PM.png)
