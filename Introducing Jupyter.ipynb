# %% [markdown]
# **Introducing Jupyter Certificate**

# %% [markdown]
# ![Screen%20Shot%202022-01-15%20at%2012.28.57%20PM.png](attachment:Screen%20Shot%202022-01-15%20at%2012.28.57%20PM.png)
